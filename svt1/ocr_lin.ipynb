# %%
import os
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path
from collections import Counter

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


from datetime import datetime

def get_timestamp() -> str:
    timestamp = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    return timestamp
import cv2

# %%
# !curl -LO https://github.com/AakashKumarNain/CaptchaCracker/raw/master/captcha_images_v2.zip
# !unzip -qq captcha_images_v2.zip

# %%
images = sorted(list(map(str, list(data_dir.glob("*.jpg")))))
# labels = [img.split(os.path.sep)[-1].split(".jpg")[0][5:] for img in images]
labels = [img.split(os.path.sep)[-1].split(".jpg")[0] for img in images]
# Out:
# 'kigo/0nかぬブSがYナ.jpg'

# %%
# Path to the data directory
# data_dir = Path("./captcha_images_v2/")
# data_dir = Path("./crop/")
data_dir = Path("./kigo/")

# Get list of all the images
# images = sorted(list(map(str, list(data_dir.glob("*.png")))))
images = sorted(list(map(str, list(data_dir.glob("*.jpg")))))
# labels = [img.split(os.path.sep)[-1].split(".jpg")[0][5:] for img in images]
labels = [img.split(os.path.sep)[-1].split(".jpg")[0] for img in images]
# print(labels)
characters = set(char for label in labels for char in label)

print("Number of images found: ", len(images))
print("Number of labels found: ", len(labels))
print("Number of unique characters: ", len(characters))
print("Characters present: ", characters)

# Batch size for training and validation
batch_size = 64

# Desired image dimensions
img_width = 512
img_height = 64

# Factor by which the image is going to be downsampled
# by the convolutional blocks. We will be using two
# convolution blocks and each block will have
# a pooling layer which downsample the features by a factor of 2.
# Hence total downsampling factor would be 4.
downsample_factor = 4

# Maximum length of any captcha in the dataset
max_length = max([len(label) for label in labels])
# Out:
# Number of images found:  10000
# Number of labels found:  10000
# Number of unique characters:  214
# Characters present:  {'ボ', 'c', 'て', 'に', 'ス', 'y', '4', 'ル', 's', 'ア', 'ユ', 'ひ', 'き', 'づ', 'ソ', 'マ', 'ほ', 'ゼ', 'u', 'ロ', 'ヱ', 'ニ', 'の', 'デ', 'ワ', 'が', 'オ', 'E', 'レ', 'ペ', 'く', 'ば', 'N', 'ダ', 'ジ', 'h', 'k', 'な', 'モ', 'ヤ', 'v', 'j', 'エ', 'た', '6', 'ホ', 'ゆ', 'ま', 'B', 'や', 'ギ', 'り', 'ヨ', 'ぬ', 'う', 'ぴ', 'ぱ', 'び', 'm', 'g', 'つ', 'よ', 'ど', 'ミ', 'ぢ', 'r', 'ヺ', 'ベ', 'い', 'ヷ', 'n', 'ラ', '2', 'P', 'グ', 'ド', 'ヒ', 'ヂ', 'ポ', 'b', 'S', 'R', 'カ', 'そ', 'せ', 'シ', 'ゔ', 'l', 'え', 'パ', 'ヰ', 'D', '3', 'ン', 'ゐ', 'A', 'X', 'プ', 'G', 'K', 'ぜ', 'バ', 'L', 'ヸ', 'る', 'ざ', 'f', 'ヴ', 'ツ', 'U', 'ピ', 'ぽ', 'サ', 'コ', 'ケ', '1', 'ぺ', 'd', 'も', 'Z', '8', 'メ', 'q', 'む', 'こ', 'F', 'だ', 'み', 'ゑ', 'w', 'タ', 'め', 'ノ', 'x', 't', 'さ', 'ふ', 'ト', 'ム', 'ぶ', 'ぼ', 'J', 'キ', 'テ', 'じ', '9', 'o', 'れ', 'i', 'へ', 'ナ', 'ゴ', 'Q', 'V', 'Y', 'ゾ', 'ず', '7', 'p', 'ヲ', 'ヅ', 'ら', 'ヌ', 'で', 'ね', 'ろ', 'あ', 'か', 'ガ', 'す', 'リ', 'ぎ', 'ネ', 'べ', 'を', 'し', 'O', 'イ', 'ヘ', '5', 'お', 'ご', 'ブ', '0', 'フ', 'セ', 'け', 'ん', 'と', 'ぞ', 'ぐ', 'z', 'M', 'I', 'a', 'わ', 'W', 'ウ', 'ゲ', 'ズ', 'は', 'ク', 'C', 'T', 'ハ', 'げ', 'チ', 'ヹ', 'ビ', 'H', 'ザ', 'ち', 'ぷ', 'e'}

# %%
max_length
# Out:
# 24

# %%
char2id = {}
id2char = {}
for i,x in enumerate(list(characters)):
    char2id[x] = i
    
# print(char2id)
for i,x in enumerate(list(characters)):
    id2char[i] = x
    
# print(id2char)

def char_to_num(char):
#     res=[]
    res = np.ones(64) - 2
    for i,c in enumerate(char):
#         print(c)
#         res.append(char2id[c])
        res[i] = char2id[c]
    return res

def num_to_char(num):
    res = []
    for n in num.numpy():
        if n in id2char.keys():
            res.append(id2char[n])
        else:
            res.append('?')
    return res


def split_data(images, labels, train_size=0.9, shuffle=True):
    # 1. Get the total size of the dataset
    size = len(images) 
    # 2. Make an indices array and shuffle it, if required
    indices = np.arange(size)
    if shuffle:
        np.random.shuffle(indices)
    # 3. Get the size of training samples
    train_samples = int(size * train_size)
    # 4. Split data into training and validation sets
    x_train, y_train = images[indices[:train_samples]], labels[indices[:train_samples]]
    x_valid, y_valid = images[indices[train_samples:]], labels[indices[train_samples:]]
#     return x_train[0:1], x_valid[0:1], y_train[0:1], y_valid[0:1]
    return x_train, x_valid, y_train, y_valid



# Splitting data into training and validation sets
x_train, x_valid, c_train, c_valid = split_data(np.array(images), np.array(labels))

y_train=[]
for i in c_train:
    y_train.append(char_to_num(i))
# y_train = np.array(y_train,dtype=np.int32)
# y_valid=[]
# for i in c_valid:
#     y_valid.append(char_to_num(i))
# y_valid = np.array(y_valid,dtype=np.int32)
# y_train


y_valid=[]
for i in c_valid:
#     break
    y_valid.append(char_to_num(i))

# y_train

# %%
import pickle
with open('./id2char.pkl','wb') as p:
    pickle.dump(id2char,p)
    
with open('./char2id.pkl','wb') as p:
    pickle.dump(char2id,p)

# %%
def encode_single_sample(img_path, label):
    # 1. Read image
    img = tf.io.read_file(img_path)
    # 2. Decode and convert to grayscale
    img = tf.io.decode_png(img, channels=3)
    # 3. Convert to float32 in [0, 1] range
    img = tf.image.convert_image_dtype(img, tf.float32)
    # 4. Resize to the desired size
#     img = tf.image.resize(img, [img_height, img_width])
    img = tf.image.random_crop(img,(img_height, img_width,3))
#     img2 = tf.py_function(np.array(img))
    # 5. Transpose the image because we want the time
    # dimension to correspond to the width of the image.
#     img = tf.transpose(img, perm=[1, 0, 2])
    # 6. Map the characters in label to numbers

    lb_len = tf.reduce_sum(tf.cast(tf.not_equal(label, -1), tf.int64))
#     label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
    # 7. Return a dict as our model is expecting two inputs
    return {"image": img, "label": label,"label_len": lb_len}

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = (
    train_dataset.map(
        encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE
    )
    .batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

validation_dataset = tf.data.Dataset.from_tensor_slices((x_valid, y_valid))
validation_dataset = (
    validation_dataset.map(
        encode_single_sample, num_parallel_calls=tf.data.AUTOTUNE
    )
    .batch(batch_size)
    .prefetch(buffer_size=tf.data.AUTOTUNE)
)

# %%
for batch in train_dataset.take(1):
    images = batch["image"]
    labels = batch["label"]
    
    label_len = batch["label_len"]
    for i in range(10):
        img = (images[i]).numpy().astype("float32")
#         print(labels[i])
#         print(labels[i].numpy())
        print(labels[i].numpy().shape)
        print(label_len[i])
        label = ''.join(num_to_char(labels[i]))
        print(label)
#         plt.imshow(img[:, :, 0], cmap="gray")
        plt.imshow(img[:, :, 0])
        plt.show()
# Out:
# (64,)
# tf.Tensor(12, shape=(), dtype=int64)
# GゑゆS6せNれ1アえp????????????????????????????????????????????????????
# (64,)
# tf.Tensor(15, shape=(), dtype=int64)
# そゼウムビぷベ6ペボuカヒ49?????????????????????????????????????????????????
# (64,)
# tf.Tensor(11, shape=(), dtype=int64)
# レズjスリのaまとそへ?????????????????????????????????????????????????????
# (64,)
# tf.Tensor(14, shape=(), dtype=int64)
# ボXQふセぐアれMひTシフダ??????????????????????????????????????????????????
# (64,)
# tf.Tensor(14, shape=(), dtype=int64)
# らgゾケ7Y4ロリヒネチザツ??????????????????????????????????????????????????
# (64,)
# tf.Tensor(13, shape=(), dtype=int64)
# ヒhウやめゼぞ9ぽヂてもヱ???????????????????????????????????????????????????
# (64,)
# tf.Tensor(12, shape=(), dtype=int64)
# げベボふヌヸrmぬぴゆ9????????????????????????????????????????????????????
# (64,)
# tf.Tensor(13, shape=(), dtype=int64)
# ねこぽどポゑ7ぢボヨdあお???????????????????????????????????????????????????
# (64,)
# tf.Tensor(16, shape=(), dtype=int64)
# vうZpルぼゐりけぺモfきえびグ????????????????????????????????????????????????
# (64,)
# tf.Tensor(9, shape=(), dtype=int64)
# リぞヹウすぐグのも???????????????????????????????????????????????????????

# %%
# config = {
# #     "alpha": 1.0,
# #     "minimalistic": True,
#     "weights": "imagenet",
#     "weights": None,
#     "include_top": False
# }
# input_img = layers.Input(
#     shape=(img_height,img_width,3), name="image", dtype="float32"
# )
# keras.applications.resnet50.ResNet50(input_tensor=input_img, **config).summary()

# %%
config = {
#     "alpha": 1.0,
#     "minimalistic": True,
    "weights": "imagenet",
    "weights": None,
    "include_top": False
}


class CTCLayer(layers.Layer):
    def __init__(self, name=None):
        super().__init__(name=name)
        self.loss_fn = keras.backend.ctc_batch_cost

    def call(self, y_true, y_pred,label_len):
        # Compute the training-time loss value and add it
        # to the layer using `self.add_loss()`.
        batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
        input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
        label_length = tf.cast(label_len, dtype="int64")

        input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
        label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")

        loss = self.loss_fn(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)
        # At test time, just return the computed predictions
        return y_pred

def build_model():
    # Inputs to the model
    input_img = layers.Input(
        shape=(img_height,img_width,3), name="image", dtype="float32"
    )
    labels = layers.Input(name="label", shape=(None,), dtype="float32")
    label_len = layers.Input(name="label_len", shape=(None,), dtype="float32")
    
    
    x = keras.applications.resnet50.ResNet50(input_tensor=input_img, **config).get_layer('conv2_block3_out').output

    x = layers.MaxPooling2D((2, 2), name="pool3")(x)

    print(x)
    x = layers.Dense(64, activation="relu", name="dense1")(x)
    print(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Conv2D(32,(8,1),activation="relu",kernel_initializer="he_normal")(x)
    x = layers.Lambda(lambda x: tf.squeeze(x,1),name='logits')(x)
    print(x)

    # RNNs
#     x = layers.Bidirectional(layers.LSTM(128, return_sequences=True, dropout=0.25))(x)
#     x = layers.Bidirectional(layers.LSTM(64, return_sequences=True, dropout=0.25))(x)
    # Output layer
    x = layers.Dense(
        len(characters)+1, activation="softmax", name="dense2"
    )(x)

    # Add CTC layer for calculating CTC loss at each step
    output = CTCLayer(name="ctc_loss")(labels, x,label_len)

    # Define the model
    model = keras.models.Model(
        inputs=[input_img, labels, label_len ], outputs=output, name="ocr_model_v1"
    )
    # Optimizer
    opt = keras.optimizers.Adam()
    # Compile the model and return
    model.compile(optimizer=opt)
    return model


# Get the model
model = build_model()
model.summary()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 64, 256), dtype=tf.float32, name=None), name='pool3/MaxPool:0', description="created by layer 'pool3'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 8, 64, 64), dtype=tf.float32, name=None), name='dense1/Relu:0', description="created by layer 'dense1'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 64, 32), dtype=tf.float32, name=None), name='logits/Squeeze:0', description="created by layer 'logits'")
# Model: "ocr_model_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 64, 512, 3)] 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 518, 3)   0           image[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 256, 64)  9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 256, 64)  256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 32, 256, 64)  0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 34, 258, 64)  0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 16, 128, 64)  0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 128, 64)  4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 128, 64)  256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 128, 64)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 128, 64)  36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 128, 64)  256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 16, 128, 64)  0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 128, 256) 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 16, 128, 256) 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 16, 128, 256) 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 16, 128, 256) 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 16, 128, 256) 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 16, 128, 256) 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 128, 64)  16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 128, 64)  256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 128, 64)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 128, 64)  36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 128, 64)  256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 16, 128, 64)  0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 16, 128, 256) 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 16, 128, 256) 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 16, 128, 256) 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 16, 128, 256) 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 128, 64)  16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 128, 64)  256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 128, 64)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 16, 128, 64)  36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 16, 128, 64)  256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 16, 128, 64)  0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 16, 128, 256) 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 16, 128, 256) 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 16, 128, 256) 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 16, 128, 256) 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 8, 64, 256)   0           conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# dense1 (Dense)                  (None, 8, 64, 64)    16448       pool3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8, 64, 64)    0           dense1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 1, 64, 32)    16416       dropout[0][0]
# __________________________________________________________________________________________________
# logits (Lambda)                 (None, 64, 32)       0           conv2d[0][0]
# __________________________________________________________________________________________________
# label (InputLayer)              [(None, None)]       0
# __________________________________________________________________________________________________
# dense2 (Dense)                  (None, 64, 215)      7095        logits[0][0]
# __________________________________________________________________________________________________
# label_len (InputLayer)          [(None, None)]       0
# __________________________________________________________________________________________________
# ctc_loss (CTCLayer)             (None, 64, 215)      0           label[0][0]
#                                                                  dense2[0][0]
#                                                                  label_len[0][0]
# ==================================================================================================
# Total params: 269,719
# Trainable params: 266,775
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
epochs = 30
early_stopping_patience = 3

filepath = get_timestamp() + '.ckpt'
checkpoint = keras.callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='auto', period=1)

# Add early stopping
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_loss", patience=early_stopping_patience, restore_best_weights=True
)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=epochs,
    callbacks=[early_stopping,checkpoint],
#     callbacks=[checkpoint],
)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/30
# 141/141 [==============================] - 165s 1s/step - loss: 69.2407 - val_loss: 69.9313
#
# Epoch 00001: val_loss improved from inf to 69.93131, saving model to 2021_11_09_01_51_52.ckpt
# Epoch 2/30
# 141/141 [==============================] - 166s 1s/step - loss: 68.0521 - val_loss: 68.7880
#
# Epoch 00002: val_loss improved from 69.93131 to 68.78796, saving model to 2021_11_09_01_51_52.ckpt
# Epoch 3/30
# 141/141 [==============================] - 166s 1s/step - loss: 56.1390 - val_loss: 72.7777
#
# Epoch 00003: val_loss did not improve from 68.78796
# Epoch 4/30
# 141/141 [==============================] - 166s 1s/step - loss: 25.5762 - val_loss: 43.9060
#
# Epoch 00004: val_loss improved from 68.78796 to 43.90596, saving model to 2021_11_09_01_51_52.ckpt
# Epoch 5/30
# 141/141 [==============================] - 166s 1s/step - loss: 12.3145 - val_loss: 15.1721
#
# Epoch 00005: val_loss improved from 43.90596 to 15.17208, saving model to 2021_11_09_01_51_52.ckpt
# Epoch 6/30
# 141/141 [==============================] - 166s 1s/step - loss: 8.3786 - val_loss: 16.0785
#
# Epoch 00006: val_loss did not improve from 15.17208
# Epoch 7/30
# 141/141 [==============================] - 165s 1s/step - loss: 5.9735 - val_loss: 26.0608
#
# Epoch 00007: val_loss did not improve from 15.17208
# Epoch 8/30
# 141/141 [==============================] - 165s 1s/step - loss: 5.2800 - val_loss: 6.4189
#
# Epoch 00008: val_loss improved from 15.17208 to 6.41893, saving model to 2021_11_09_01_51_52.ckpt
# Epoch 9/30
# 141/141 [==============================] - 166s 1s/step - loss: 4.5152 - val_loss: 18.3824
#
# Epoch 00009: val_loss did not improve from 6.41893
# Epoch 10/30
# 141/141 [==============================] - 165s 1s/step - loss: 3.6419 - val_loss: 3.8843
#
# Epoch 00010: val_loss improved from 6.41893 to 3.88425, saving model to 2021_11_09_01_51_52.ckpt
# Epoch 11/30
# 141/141 [==============================] - 166s 1s/step - loss: 3.1877 - val_loss: 9.5762
#
# Epoch 00011: val_loss did not improve from 3.88425
# Epoch 12/30
# 141/141 [==============================] - 166s 1s/step - loss: 3.1193 - val_loss: 4.2429
#
# Epoch 00012: val_loss did not improve from 3.88425
# Epoch 13/30
# 141/141 [==============================] - 166s 1s/step - loss: 2.6981 - val_loss: 3.2126
#
# Epoch 00013: val_loss improved from 3.88425 to 3.21265, saving model to 2021_11_09_01_51_52.ckpt
# Epoch 14/30
# 141/141 [==============================] - 166s 1s/step - loss: 2.5019 - val_loss: 3.2565
#
# Epoch 00014: val_loss did not improve from 3.21265
# Epoch 15/30
# 141/141 [==============================] - 166s 1s/step - loss: 2.3262 - val_loss: 2.7677
#
# Epoch 00015: val_loss improved from 3.21265 to 2.76768, saving model to 2021_11_09_01_51_52.ckpt
# Epoch 16/30
# 141/141 [==============================] - 167s 1s/step - loss: 2.3291 - val_loss: 6.0063
#
# Epoch 00016: val_loss did not improve from 2.76768
# Epoch 17/30
# 141/141 [==============================] - 165s 1s/step - loss: 2.2018 - val_loss: 3.5421
#
# Epoch 00017: val_loss did not improve from 2.76768
# Epoch 18/30
# 141/141 [==============================] - 166s 1s/step - loss: 2.1141 - val_loss: 3.0800
#
# Epoch 00018: val_loss did not improve from 2.76768

# %%
prediction_model = keras.models.Model(
    model.get_layer(name="image").input, keras.layers.Softmax()(model.get_layer(name="dense2").output)
    # model.get_layer(name="image").input, model.get_layer(name="separable_conv2d_1").output
)

# %%
model.input
# Out:
# [<KerasTensor: shape=(None, 64, 512, 3) dtype=float32 (created by layer 'image')>,
#  <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'label')>,
#  <KerasTensor: shape=(None, None) dtype=float32 (created by layer 'label_len')>]

# %%
from matplotlib.font_manager import FontProperties

fp = FontProperties(fname ='./msg.ttf',size =14)

def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]
#     input_len = np.ones(pred.shape[0]) * 13
    # Use greedy search. For complex tasks, you can use beam search
#     print(input_len)
    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :
    ]
    # Iterate over the results and get back the text
    output_text = []
    for res in results:
        res = tf.strings.reduce_join(num_to_char(res)).numpy().decode("utf-8")
        output_text.append(res)
    return output_text



for batch in validation_dataset.take(1):
    batch_images = batch["image"]
    batch_labels = batch["label"]
    print(batch_images.shape)
    plt.imshow(batch_images[0,...,0].numpy())
    plt.show()
    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)
#     print(pred.shape)
    print(pred_texts)
    orig_texts = []
    for label in batch_labels:
        label = tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
        orig_texts.append(label)

    _, ax = plt.subplots(4, 4, figsize=(15, 5))
#     for i in range(len(pred_texts)):
    for i in range(16):
        img = (batch_images[i, :, :] * 255).numpy().astype(np.uint8)
        img = img
        title = f"Prediction: {pred_texts[i]}"
        title = title.replace('?','')
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title, fontproperties=fp)
        ax[i // 4, i % 4].axis("off")
plt.show()
# Out:
# (64, 64, 512, 3)
# ['くゲぎけおらデwウE??????????????????????????????????????????????????????', 'カIぎラヰフDプさMち9へネと?????????????????????????????????????????????????', 'デパキぽゼヘ6iツソjぷべレ??????????????????????????????????????????????????', 'マせねHぜぴびBaヒzごげウ??????????????????????????????????????????????????', 'とlせえドもg?????????????????????????????????????????????????????????', 'べんジぷいゔホだざリLイなむhTう???????????????????????????????????????????????', 'シビべpMゼgOxeaCVK??????????????????????????????????????????????????', 'たぱグvヒヌ1UuZぶLパCれoよヅも?????????????????????????????????????????????', 'sそもゲわWボシんあうぶYベ??????????????????????????????????????????????????', 'kえとgまトウルぬたチ?????????????????????????????????????????????????????', 'Fcニuぱちカdぬひド?????????????????????????????????????????????????????', 'ヌぬぷケナキハ?????????????????????????????????????????????????????????', 'KDどずoひヌプgc3だ????????????????????????????????????????????????????', 'kUハゆダゼろよねクじゑM???????????????????????????????????????????????????', 'rてUれBダXやド???????????????????????????????????????????????????????', 'EゔウざプウづひVみg?????????????????????????????????????????????????????', 'ぢテ9まカるglル???????????????????????????????????????????????????????', 'ばげユすパ5ZきうギYG????????????????????????????????????????????????????', 'お3エんまリナベUヴ??????????????????????????????????????????????????????', 'ホyゆポしjh2mgウ?????????????????????????????????????????????????????', 'ミXワがぞじキアMaプり????????????????????????????????????????????????????', 'Fゲぴツのシホずaま9?????????????????????????????????????????????????????', 'レフリウさpコナ????????????????????????????????????????????????????????', 'せナぼゔうれパtテmヨP????????????????????????????????????????????????????', 'しビプIフダべぢワちヌ4おずzぎだ???????????????????????????????????????????????', 'kyふをKハげじサ???????????????????????????????????????????????????????', 'ゔるづchはし?????????????????????????????????????????????????????????', 'ゆYAいドネdこaWE3????????????????????????????????????????????????????', 'dpゔパウマヘるまざ??????????????????????????????????????????????????????', 'ヂLゆjづらじぐ????????????????????????????????????????????????????????', 'CさタムOピべぐエヰ??????????????????????????????????????????????????????', 'ひヅxホ9vりずkヌL?????????????????????????????????????????????????????', 'ヅみボRソびoぐを???????????????????????????????????????????????????????', 'GVづスどばにでリこそわゲプヤo????????????????????????????????????????????????', 'amデゆfぞジxヰじGヤsべゔぎロをハホら???????????????????????????????????????????', 'ヨZヒフメぼウnぱヂウド????????????????????????????????????????????????????', 'ズび9Oあゴげ5せ???????????????????????????????????????????????????????', 'ちナyのゆnSギピぬKバわ???????????????????????????????????????????????????', 'ニポユズpDねぎ????????????????????????????????????????????????????????', 'デほむブアツスマpパOゑ????????????????????????????????????????????????????', 'はlザもねぽくWソチム?????????????????????????????????????????????????????', 'eヅFゑまくにぎぜBパケルピ??????????????????????????????????????????????????', 'がQWこウおqb????????????????????????????????????????????????????????', 'のマじやRノaウEUqjゔ???????????????????????????????????????????????????', 'AイXfぱずF6ガエサグネlキ?????????????????????????????????????????????????', 'jふOレやAぼソなタぎぢ????????????????????????????????????????????????????', 'あゔjヱgTヅゼめテばXみ???????????????????????????????????????????????????', 'ゆそイマTQsヰムこ??????????????????????????????????????????????????????', 'きとヂRビeノtCrザ2ぱ???????????????????????????????????????????????????', 'ビラかナシづごゑ6ロヰ5びゲバぶマミろ9????????????????????????????????????????????', 'kaづUむやぎミラぢニw4sL3ズぺ??????????????????????????????????????????????', 'ぎiワPUピアぐだのVcガXH?????????????????????????????????????????????????', 'どEイwxタルSピVぶ?????????????????????????????????????????????????????', 'bペmユゑわ5ねこ???????????????????????????????????????????????????????', 'zDぐガトゴぬうぢでこみずe??????????????????????????????????????????????????', 'ユハゲそひマtをホトダk????????????????????????????????????????????????????', 'なZすD5ステりさチぐよTガナシユCえR????????????????????????????????????????????', 'ぶスぬガゔヘづざwgあゲえツくね????????????????????????????????????????????????', 'lビちにhヨq7?????????????????????????????????????????????? ...
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12436 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
for batch in train_dataset.take(1):
    batch_images = batch["image"]
    batch_labels = batch["label"]
#     print(batch_images.shape)
#     plt.imshow(batch_images[0,...,0].numpy().T)
#     plt.show()
    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)
#     print(pred.shape)
#     print(pred_texts)
    print('train_dataset')
    orig_texts = []
    for label in batch_labels:
        label = tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
        orig_texts.append(label)

    _, ax = plt.subplots(4, 4, figsize=(20, 5))
    for i in range(16):
        img = (batch_images[i, :, :] * 255).numpy().astype(np.uint8)
        img = img
        title = f"Prediction: {pred_texts[i]}"
        title = title.replace('?','')
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title, fontproperties=fp)
        ax[i // 4, i % 4].axis("off")
plt.show()
for batch in validation_dataset.take(3):
    batch_images = batch["image"]
    batch_labels = batch["label"]
#     print(batch_images.shape)
#     plt.imshow(batch_images[0,...,0].numpy().T)
#     plt.show()
    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)
#     print(pred.shape)
#     print(pred_texts)
    print('valid_dataset')
    orig_texts = []
    for label in batch_labels:
        label = tf.strings.reduce_join(num_to_char(label)).numpy().decode("utf-8")
        orig_texts.append(label)

    _, ax = plt.subplots(4, 4, figsize=(20, 5))
    for i in range(16):
        img = (batch_images[i, :, :] * 255).numpy().astype(np.uint8)
        img = img
        title = f"Prediction: {pred_texts[i]}"
        title = title.replace('?','')
        ax[i // 4, i % 4].imshow(img, cmap="gray")
        ax[i // 4, i % 4].set_title(title, fontproperties=fp)
        ax[i // 4, i % 4].axis("off")
plt.show()
# Out:
# train_dataset
# valid_dataset
# valid_dataset
# valid_dataset
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12535 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12535 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12538 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12538 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def resize_pad(img, h, w):
    w_new = int(h / img.shape[0] * img.shape[1])
    img = cv2.resize(img, (w_new, h), cv2.INTER_AREA)
    if img.shape[1] >= w: return img[:, :w], w // 16
    padded = np.zeros((h, w, 3)).astype(img.dtype)
    padded[:, :img.shape[1]] = img
    return padded, img.shape[1] // 16

# %%
# workspace/dense.release/svt1/photo_2021-10-29_00-41-41.jpg
# workspace/dense.release/svt1/Screenshot from 2021-11-01 16-16-36.png
# workspace/dense.release/svt1/photo_2021-10-29_00-41-41.jpg
# workspace/dense.release/svt1/Screenshot from 2021-11-01 18-11-57.png
# workspace/dense.release/svt1/photo_2021-11-06_16-41-26.jpg
# workspace/dense.release/svt1/photo_2021-11-07_10-11-38.jpg
# workspace/dense.release/svt1/photo_2021-11-07_10-12-50.jpg
img = cv2.imread('photo_2021-11-06_03-58-00.jpg')

# img = cv2.resize(img,(200,64))

# pad[:img.shape[0],:img.shape[1]] = img
# img = pad
# plt.imshow(img)
# plt.show()
# img = cv2.cvtColor(img,cv2.COLOR_BAYER_BG2RGB)
# plt.imshow(img[:,0:290])
# img = img[:,0:290]
img,_ = resize_pad(img,64,512)
# img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
# img[img>200] = 255
# img[img<200] = 0
plt.imshow(img)
plt.show()
img = img[np.newaxis,...].astype(np.float64) /255
preds = prediction_model.predict(img)
pred_texts = decode_batch_predictions(preds)

pred_texts
# Out:
# ['きをゔゔあまDぬいミミをヨ???????????????????????????????????????????????????']

# %%
from PIL import ImageFont, ImageDraw, Image

def gen(text,h,w,fontSize):
    img = np.ones([h,w,3],dtype=np.uint8) *255
    fontpath ='./msg.ttf' # Windows10 だと C:\Windows\Fonts\ 以下にフォントがあります。
    b,g,r,a = 0,0,0,0 #B(青)・G(緑)・R(赤)・A(透明度)
    font = ImageFont.truetype(fontpath, fontSize) # フォントサイズが32
    img_pil = Image.fromarray(img) # 配列の各値を8bit(1byte)整数型(0～255)をPIL Imageに変換。
    draw = ImageDraw.Draw(img_pil) # drawインスタンスを生成
    message = text
    position = (0, 4) # テキスト表示位置
    draw.text(position, message, font = font , fill = (b, g, r, a) ) # drawにテキストを記載 fill:色 BGRA (RGB)
    img = np.array(img_pil) # PIL を配列に変換
    return img
img = gen('',64,512,50)
# img = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(img)
img = img[np.newaxis,...].astype(np.float64) /255
preds = prediction_model.predict(img)
pred_texts = decode_batch_predictions(preds)

pred_texts
# Out:
# ['????????????????????????????????????????????????????????????????']

# %%
prediction_model.save('model.h5')
